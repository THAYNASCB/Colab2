# %% [markdown]
# <a href="https://colab.research.google.com/github/THAYNASCB/Colab2/blob/main/AA_THAYN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# numero identificador unico para cada usuario, iniciando com valor 1, v.02
identificadorUsuarios = 1

# inicializando a lista de contatos vazia
lista = [] 

def existe_contato(nome):
  if len(lista) > 0:
    for contato in lista:
      if contato['nome'] == nome:
        return True
  return False

def adicionarUsuarios(num):
  while(num > 0):
    email = input("Digite e-mail do contato:")
    nome = input("Digite o nome:")
    telefone = input("Digite o telefone:")
    twitter = input("twitter:")
    instagram = input("instagram:")

    if existe_contato(nome): 
      print ("Erro: Esse nome já está cadastrado.")
      return
    
    global identificadorUsuarios

    #nome único de contato
    contato = {
    "id": identificadorUsuarios,
    "email":email,
    "nome":nome,
    "tel": telefone,
    "twitter": twitter,
    "instagram": instagram
    }
    lista.append(contato)
    print("O contato {} foi cadastrado com sucesso\n".format(contato['nome']))
    num -= 1
    identificadorUsuarios += 1

def adicionar():
  email = input("Digite e-mail do contato:")
  nome = input("Digite o nome:")
  telefone = input("Digite o telefone:")
  twitter = input("twitter:")
  instagram = input("instagram:")

  if existe_contato(nome): 
    print ("Erro: Esse nome já está cadastrado.")
    return
  
  global identificadorUsuarios

  #email único de contato
  contato = {
  "id": identificadorUsuarios,
  "email":email,
  "nome":nome,
  "tel": telefone,
  "twitter": twitter,
  "instagram": instagram
  }
  lista.append(contato)
  identificadorUsuarios += 1
  print("O contato {} foi cadastrado com sucesso\n".format(contato['nome']))

def alterar(nome):
  if existe_contato(nome):
    email = input("Digite o email:")
    telefone = input("Digite o telefone:")
    twitter = input("twitter:")
    instagram = input("instagram:")
    indice: int = 0
    for contato in lista:
       if contato['nome']==nome:
         break;
       indice = indice + 1
    lista[indice]['email'] = email
    lista[indice]['tel'] = telefone
    lista[indice]['twitter'] = twitter
    lista[indice]['instagram'] = instagram
    print("O contato {} foi alterado com sucesso\n".format(email))
  else:
    print("O contato {} não foi encontrado\n".format(nome))

def excluir(nome):
  if existe_contato(nome): 
    indice = 0
    for contato in lista:
       if contato['nome']==nome:
         break;
       indice = indice + 1
    del lista[indice]
    print("O contato {} foi excluido com sucesso\n".format(nome))
  else:
    print("O contato {} não foi encontrado\n".format(nome))
  
def buscarPorNome(nome):
  if len(lista) > 0:
    for contato in lista:
       if contato['nome']==nome:
          print(contato['id'])
          print(contato['email'])
          print(contato['tel'])
          print(contato['twitter'])
          print(contato['instagram'])

def listar():
  for contato in lista:
    print(contato['id'])
    print(contato['email'])
    print(contato['nome'])
    print(contato['tel'])
    print(contato['twitter'])
    print(contato['instagram'])

def menu():
  while True:
    print("===Agenda Telefônica===")
    print("1 - Adicionar contato")
    print("2 - Alterar contato")
    print("3 - Excluir contato")
    print("4 - Buscar contato por nome4")
    print("5 - Listar contatos")
    print("6 - Incluir mais de um contato ao mesmo tempo")
    print("7 - Sair")
    opcao = int (input(">"))
    if opcao == 1:
      adicionar()
    elif opcao == 2:
      nome = input("Digite nome do contato que deseja alterar:")
      alterar(nome)
    elif opcao == 3:
      nome = input("Digite nome do contato que deseja excluir:")
      excluir(nome)
    elif opcao == 4:
      nome = input("Digite nome do contato que deseja buscar:")
      buscarPorNome(nome)
    elif opcao == 5:
      listar()
    elif opcao == 6:
      num = int (input("Digite o número de usuários a serem cadastrados:"))
      adicionarUsuarios(num)
    elif opcao ==7:
      print("Saindo do programa...")
      break
    else:
      print("Opção inválida. Por favor, tente novamente!") 

menu()
# Out:
# ===Agenda Telefônica===
# 1 - Adicionar contato
# 2 - Alterar contato
# 3 - Excluir contato
# 4 - Buscar contato por nome4
# 5 - Listar contatos
# 6 - Incluir mais de um contato ao mesmo tempo
# 7 - Sair
# >1
# Digite e-mail do contato:e1
# Digite o nome:n1
# Digite o telefone:tel1
# twitter:tw1
# instagram:in1
# O contato n1 foi cadastrado com sucesso
#
# ===Agenda Telefônica===
# 1 - Adicionar contato
# 2 - Alterar contato
# 3 - Excluir contato
# 4 - Buscar contato por nome4
# 5 - Listar contatos
# 6 - Incluir mais de um contato ao mesmo tempo
# 7 - Sair
# >3
# Digite nome do contato que deseja excluir:n1
# O contato n1 foi excluido com sucesso
#
# ===Agenda Telefônica===
# 1 - Adicionar contato
# 2 - Alterar contato
# 3 - Excluir contato
# 4 - Buscar contato por nome4
# 5 - Listar contatos
# 6 - Incluir mais de um contato ao mesmo tempo
# 7 - Sair
# >7
# Saindo do programa...

# %%
contatos{}
